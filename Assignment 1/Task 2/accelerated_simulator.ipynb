# %% [markdown]
# <a href="https://colab.research.google.com/github/spino17/CS671-Deep-Learning-2019/blob/master/accelerated_simulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
# loads the data from the given files
masses = tf.Variable(np.load('masses.npy'), dtype = tf.float32) # mass vec
r = tf.Variable(np.load('positions.npy'), dtype = tf.float32) # positions vec
v = tf.Variable(np.load('velocities.npy'), dtype = tf.float32) # velocities vec
G = tf.Variable(6.67 * (10 ** 5)) # gravitaional constant
flag = tf.Variable(0) # stores threshold separtion condition flag

# %%
num_particle = 100
num_dim = 2
r_threshold = 0.1
time_step = 10 ** (-4)

r_x = r[:, 0] # x component of positions vec
r_y = r[:, 1] # y component of positions vec
outer_rx = tf.cast(tf.transpose([r_x]) - r_x, dtype = tf.float32)
outer_ry = tf.cast(tf.transpose([r_y]) - r_y, dtype = tf.float32)
square_outer_x = tf.cast(tf.square(outer_rx), dtype = tf.float32)
square_outer_y = tf.cast(tf.square(outer_ry), dtype = tf.float32)
dist_mat = tf.sqrt(square_outer_x + square_outer_y) # separation matrix
dist_mat = tf.matrix_set_diag(dist_mat, tf.ones(num_particle))
check_threshold = tf.cond(tf.size(tf.where(tf.less_equal(dist_mat, r_threshold))) > 0, lambda: tf.assign(flag, 1), lambda: tf.assign(flag, 0))
dist_mat = tf.reciprocal(dist_mat)
dist_mat = tf.cast(G * tf.pow(dist_mat, 3), dtype = tf.float32)
dist_mat = tf.matrix_set_diag(dist_mat, tf.zeros(num_particle))
dist_mat_x = tf.multiply(dist_mat, outer_rx)
dist_mat_y = tf.multiply(dist_mat, outer_ry)
acc_x = tf.matmul(dist_mat_x, tf.reshape(masses, [tf.size(masses), 1]))
acc_y = tf.matmul(dist_mat_y, tf.reshape(masses, [tf.size(masses), 1]))
acc_x = tf.reshape(acc_x, [tf.size(acc_x), 1])
acc_y = tf.reshape(acc_y, [tf.size(acc_y), 1])
acc_mat = tf.concat([acc_x, acc_y], 1) # acceleration matrix
update_r = tf.assign(r, r + time_step * v + (1 / 2) * (time_step ** 2) * acc_mat) # update the configuration r
update_v = tf.assign(v, v + time_step * acc_mat) # update the configuration v

# %%
sess = tf.Session() # declare the sesion
sess.run(tf.global_variables_initializer()) # initialize all variables
threshold_cond = 0 # initally condition is not satisified
counter = 0

while (threshold_cond == 0):
  threshold_cond = sess.run(check_threshold)
  r_new, v_new = sess.run([update_r, update_v]) # new values of r and v
  counter += 1
  print("iter no. : %d, flag value: %d" % (counter, threshold_cond))
  
print(r_new, v_new)
# Out:
# iter no. : 1, flag value: 0
# iter no. : 2, flag value: 0
# iter no. : 3, flag value: 0
# iter no. : 4, flag value: 0
# iter no. : 5, flag value: 0
# iter no. : 6, flag value: 0
# iter no. : 7, flag value: 0
# iter no. : 8, flag value: 0
# iter no. : 9, flag value: 0
# iter no. : 10, flag value: 0
# iter no. : 11, flag value: 0
# iter no. : 12, flag value: 0
# iter no. : 13, flag value: 0
# iter no. : 14, flag value: 0
# iter no. : 15, flag value: 0
# iter no. : 16, flag value: 0
# iter no. : 17, flag value: 0
# iter no. : 18, flag value: 0
# iter no. : 19, flag value: 0
# iter no. : 20, flag value: 0
# iter no. : 21, flag value: 0
# iter no. : 22, flag value: 0
# iter no. : 23, flag value: 0
# iter no. : 24, flag value: 0
# iter no. : 25, flag value: 0
# iter no. : 26, flag value: 0
# iter no. : 27, flag value: 0
# iter no. : 28, flag value: 0
# iter no. : 29, flag value: 0
# iter no. : 30, flag value: 0
# iter no. : 31, flag value: 0
# iter no. : 32, flag value: 0
# iter no. : 33, flag value: 0
# iter no. : 34, flag value: 0
# iter no. : 35, flag value: 0
# iter no. : 36, flag value: 0
# iter no. : 37, flag value: 0
# iter no. : 38, flag value: 0
# iter no. : 39, flag value: 0
# iter no. : 40, flag value: 0
# iter no. : 41, flag value: 0
# iter no. : 42, flag value: 0
# iter no. : 43, flag value: 0
# iter no. : 44, flag value: 0
# iter no. : 45, flag value: 0
# iter no. : 46, flag value: 0
# iter no. : 47, flag value: 0
# iter no. : 48, flag value: 0
# iter no. : 49, flag value: 0
# iter no. : 50, flag value: 0
# iter no. : 51, flag value: 0
# iter no. : 52, flag value: 0
# iter no. : 53, flag value: 0
# iter no. : 54, flag value: 0
# iter no. : 55, flag value: 0
# iter no. : 56, flag value: 0
# iter no. : 57, flag value: 0
# iter no. : 58, flag value: 0
# iter no. : 59, flag value: 0
# iter no. : 60, flag value: 0
# iter no. : 61, flag value: 0
# iter no. : 62, flag value: 0
# iter no. : 63, flag value: 0
# iter no. : 64, flag value: 0
# iter no. : 65, flag value: 0
# iter no. : 66, flag value: 0
# iter no. : 67, flag value: 0
# iter no. : 68, flag value: 0
# iter no. : 69, flag value: 0
# iter no. : 70, flag value: 0
# iter no. : 71, flag value: 0
# iter no. : 72, flag value: 0
# iter no. : 73, flag value: 0
# iter no. : 74, flag value: 0
# iter no. : 75, flag value: 0
# iter no. : 76, flag value: 0
# iter no. : 77, flag value: 0
# iter no. : 78, flag value: 0
# iter no. : 79, flag value: 0
# iter no. : 80, flag value: 0
# iter no. : 81, flag value: 0
# iter no. : 82, flag value: 0
# iter no. : 83, flag value: 0
# iter no. : 84, flag value: 0
# iter no. : 85, flag value: 0
# iter no. : 86, flag value: 0
# iter no. : 87, flag value: 0
# iter no. : 88, flag value: 0
# iter no. : 89, flag value: 0
# iter no. : 90, flag value: 0
# iter no. : 91, flag value: 0
# iter no. : 92, flag value: 0
# iter no. : 93, flag value: 0
# iter no. : 94, flag value: 0
# iter no. : 95, flag value: 0
# iter no. : 96, flag value: 0
# iter no. : 97, flag value: 0
# iter no. : 98, flag value: 0
# iter no. : 99, flag value: 0
# iter no. : 100, flag value: 0
# iter no. : 101, flag value: 0
# iter no. : 102, flag value: 0
# iter no. : 103, flag value: 0
# iter no. : 104, flag value: 0
# iter no. : 105, flag value: 0
# iter no. : 106, flag value: 0
# iter no. : 107, flag value: 0
# iter no. : 108, flag value: 0
# iter no. : 109, flag value: 0
# iter no. : 110, flag value: 0
# iter no. : 111, flag value: 0
# iter no. : 112, flag value: 0
# iter no. : 113, flag value: 0
# iter no. : 114, flag value: 0
# iter no. : 115, flag value: 0
# iter no. : 116, flag value: 0
# iter no. : 214, flag value: 0
# iter no. : 215, flag value: 0
# iter no. : 216, flag value: 0
# iter no. : 217, flag value: 0
# iter no. : 218, flag value: 0
# iter no. : 219, flag value: 0
# iter no. : 220, flag value: 0
# iter no. : 221, flag value: 0
# iter no. : 222, flag value: 0
# iter no. : 223, flag value: 0
# iter no. : 224, flag value: 0
# iter no. : 225, flag value: 0
# iter no. : 226, flag value: 0
# iter no. : 227, flag value: 0
# iter no. : 228, flag value: 0
# iter no. : 229, flag value: 0
# iter no. : 230, flag value: 0
# iter no. : 231, flag value: 0
# iter no. : 232, flag value: 0
# iter no. : 233, flag value: 0
# iter no. : 234, flag value: 0
# iter no. : 235, flag value: 0
# iter no. : 236, flag value: 0
# iter no. : 237, flag value: 1
# [[ 7.51126328e+01 -1.45389267e+02]
#  [-9.87210941e+00  6.78118210e+01]
#  [ 7.86154861e+01 -1.41235931e+02]
#  [-1.31147934e+02 -1.56943878e+02]
#  [-5.96321983e+01  3.55863251e+02]
#  [ 6.45169983e+01 -1.44945160e+02]
#  [ 4.23106537e+01 -1.33591049e+02]
#  [-3.67772522e+01  3.18027077e+01]
#  [ 1.39564676e+01  9.98632431e+01]
#  [-1.96940598e+02  2.38736606e+00]
#  [-3.68101959e+01 -3.65980492e+01]
#  [ 1.04433250e+01 -1.27504898e+02]
#  [-9.72949219e+01  2.64453487e+01]
#  [-3.59613533e+01  2.35597515e+01]
#  [-1.26679230e+02  3.67110863e+01]
#  [ 1.06726933e+01  2.04476395e+02]
#  [ 3.90703392e+01 -1.47458542e+02]
#  [ 3.13671936e+02 -7.58588257e+01]
#  [ 8.72361603e+01  1.63329834e+02]
#  [ 5.63562431e+01 -1.39672607e+02]
#  [ 6.92522354e+01  1.23017387e+02]
#  [-2.60481171e+02  1.24106705e+02]
#  [-8.15275955e+01  4.65702896e+01]
#  [ 4.50315285e+01 -1.30850723e+02]
#  [ 1.81915268e+02 -3.94654968e+02]
#  [ 2.25100117e+01  1.23620377e+02]
#  [ 5.55118065e+01 -1.38297440e+02]
#  [-1.95902908e+02  4.45151100e+01]
#  [ 4.60958147e+00  7.39274750e+01]
#  [ 8.28278122e+01 -1.27021667e+02]
#  [-4.82132721e+00 -2.20340668e+02]
#  [-3.09200165e+02 -8.14645615e+01]
#  [ 5.61265678e+01  1.40958328e+02]
#  [ 5.11178970e+01  3.29980469e+01]
#  [ 2.23107014e+01  7.38573227e+01]
#  [ 6.07781143e+01 -1.26272125e+02]
#  [ 1.23367943e+02  1.69458328e+02]
#  [-9.07263184e+01  1.09837814e+02]
#  [ 1.24092951e+01 -1.35218613e+02]
#  [-8.05666809e+01 -1.33317917e+02]
#  [-5.12627106e+01 -6.39838295e+01]
#  [-7.17258530e+01  1.09749275e+02]
#  [ 2.63341331e+01  1.14882057e+02]
#  [-3.21566544e+01 -1.18771484e+02]
#  [-3.96668816e+01  3.73011284e+01]
#  [ 1.59452677e+01  3.43236732e+01]
#  [-1.20190132e+02  1.99703770e+01]
#  [-6.64903412e+01  3.78865776e+01]
#  [-5.37271843e+01  4.34070435e+01]
#  [   354.6028     6701.5083  ]
#  [  7359.5107    -4660.7905  ]
#  [  5505.0186     3014.613   ]
#  [ -9447.838      2167.5828  ]
#  [ -1452.3676     3640.0178  ]
#  [  2727.7263    -4738.61    ]
#  [ 11409.224    -14948.172   ]
#  [  1051.7233     2544.3843  ]
#  [  2111.898     -4118.353   ]
#  [ -6738.105      -977.1436  ]
#  [  1121.8596     1883.7799  ]
#  [  3072.4924    -3658.1936  ]
#  [ -1645.9753   -11329.447   ]
#  [-12236.981       599.2255  ]
#  [  4581.8994     5200.8794  ]
#  [  5053.9526    -1170.0647  ]
#  [  2829.8606     1011.34033 ]
#  [  2245.5918    -4263.1743  ]
#  [  2052.1602     7754.713   ]
#  [ -1762.6725     7474.1553  ]
#  [  1765.0764    -5250.8647  ]
#  [ -5342.7305    -7326.122   ]
#  [ -3781.0447    -2970.8606  ]
#  [  -855.33124    2016.4816  ]
#  [  1154.5533     2602.3616  ]
#  [ -3569.9111    -7286.005   ]
#  [   144.60461    1875.695   ]
#  [  3312.9055     -707.0502  ]
#  [ -3313.5872     -530.6276  ]
#  [  -926.89526    2898.2202  ]
#  [  -706.86896    4045.685   ]
#  [  3300.086     -3504.4333  ]
#  [  1359.011      -380.7587  ]
#  [  1150.2634    -6514.061   ]
#  [ 10605.289      5602.9004  ]
#  [   113.08851    1359.2976  ]
#  [  1813.9551     5947.1724  ]
#  [  4755.324     -6534.863   ]
#  [ -2664.2632     1358.8185  ]
#  [   844.18164    4772.054   ]
#  [  4275.619     -4065.271   ]
#  [  2995.5833     3841.9697  ]
#  [  4535.3145    -3398.5422  ]
#  [  1917.097      3716.0127  ]
#  [   971.3068     6742.7915  ]
#  [  2261.692     -4129.5586  ]
#  [ -4655.405      3092.4124  ]
#  [ -5474.882     -2784.345   ]
#  [  1635.6906    -3888.722   ]
#  [  1264.5585     3061.1829  ]
#  [ -5293.1353     5082.955   ]
#  [   908.5119     4223.312   ]
#  [   120.2802     4014.726   ]
#  [   987.914      1338.2188  ]
#  [ -2946.5786    -8752.419   ]
#  [  2745.3462    -3371.6255  ]
#  [  5017.8887     3895.0269  ]
#  [  -922.3329     2764.0017  ]
#  [  4043.202     -6240.827   ]
#  [ -2876.0571     8513.336   ]
#  [ 11094.498     -8819.989   ]
#  [   925.81085    3369.0203  ]
#  [ -8594.048     -9148.472   ]
#  [  3315.5867    -3070.801   ]
#  [  -687.3174     1747.9294  ]
#  [ 47234.46     -46150.7     ]
#  [   112.92257    2534.0457  ]
#  [ -1416.5367    -7554.5303  ]
#  [ -1357.193     -3923.341   ]
#  [ -5168.6436     -479.4745  ]
#  [  4192.708      1846.1012  ]
#  [ -8707.229      4627.639   ]
#  [  -119.512924   5137.493   ]
#  [   273.60635    2476.419   ]
#  [   465.0337     1729.4052  ]
#  [  2139.2878    -5480.8374  ]
#  [  1149.0562     2197.3794  ]
#  [  1790.4183     6196.3813  ]
#  [  -547.97284    3646.2507  ]
#  [  7363.207     -3715.1343  ]
#  [ -6654.5366     3506.2668  ]
#  [  1544.1632    -4194.6973  ]]
